# %%
import numpy as np

# %%
import gensim.corpora as corpora
from gensim.models.coherencemodel import CoherenceModel

# %%
# !pip install bertopic
# Out:
# Collecting bertopic
#   Downloading bertopic-0.10.0-py2.py3-none-any.whl (58 kB)
#      |████████████████████████████████| 58 kB 4.6 MB/s
# Requirement already satisfied: pyyaml<6.0 in /usr/local/lib/python3.7/dist-packages (from bertopic) (3.13)
# Requirement already satisfied: scikit-learn>=0.22.2.post1 in /usr/local/lib/python3.7/dist-packages (from bertopic) (1.0.2)
# Collecting umap-learn>=0.5.0
#   Downloading umap-learn-0.5.3.tar.gz (88 kB)
#      |████████████████████████████████| 88 kB 6.5 MB/s
# Requirement already satisfied: numpy>=1.20.0 in /usr/local/lib/python3.7/dist-packages (from bertopic) (1.21.6)
# Requirement already satisfied: plotly>=4.7.0 in /usr/local/lib/python3.7/dist-packages (from bertopic) (5.5.0)
# Requirement already satisfied: tqdm>=4.41.1 in /usr/local/lib/python3.7/dist-packages (from bertopic) (4.64.0)
# Collecting hdbscan>=0.8.28
#   Downloading hdbscan-0.8.28.tar.gz (5.2 MB)
#      |████████████████████████████████| 5.2 MB 46.7 MB/s
#   Installing build dependencies ... done
#   Getting requirements to build wheel ... done
#     Preparing wheel metadata ... done
# Collecting sentence-transformers>=0.4.1
#   Downloading sentence-transformers-2.2.0.tar.gz (79 kB)
#      |████████████████████████████████| 79 kB 7.8 MB/s
# Requirement already satisfied: pandas>=1.1.5 in /usr/local/lib/python3.7/dist-packages (from bertopic) (1.3.5)
# Requirement already satisfied: scipy>=1.0 in /usr/local/lib/python3.7/dist-packages (from hdbscan>=0.8.28->bertopic) (1.4.1)
# Requirement already satisfied: joblib>=1.0 in /usr/local/lib/python3.7/dist-packages (from hdbscan>=0.8.28->bertopic) (1.1.0)
# Requirement already satisfied: cython>=0.27 in /usr/local/lib/python3.7/dist-packages (from hdbscan>=0.8.28->bertopic) (0.29.28)
# Requirement already satisfied: python-dateutil>=2.7.3 in /usr/local/lib/python3.7/dist-packages (from pandas>=1.1.5->bertopic) (2.8.2)
# Requirement already satisfied: pytz>=2017.3 in /usr/local/lib/python3.7/dist-packages (from pandas>=1.1.5->bertopic) (2022.1)
# Requirement already satisfied: six in /usr/local/lib/python3.7/dist-packages (from plotly>=4.7.0->bertopic) (1.15.0)
# Requirement already satisfied: tenacity>=6.2.0 in /usr/local/lib/python3.7/dist-packages (from plotly>=4.7.0->bertopic) (8.0.1)
# Requirement already satisfied: threadpoolctl>=2.0.0 in /usr/local/lib/python3.7/dist-packages (from scikit-learn>=0.22.2.post1->bertopic) (3.1.0)
# Collecting transformers<5.0.0,>=4.6.0
#   Downloading transformers-4.18.0-py3-none-any.whl (4.0 MB)
#      |████████████████████████████████| 4.0 MB 29.8 MB/s
# Requirement already satisfied: torch>=1.6.0 in /usr/local/lib/python3.7/dist-packages (from sentence-transformers>=0.4.1->bertopic) (1.11.0+cu113)
# Requirement already satisfied: torchvision in /usr/local/lib/python3.7/dist-packages (from sentence-transformers>=0.4.1->bertopic) (0.12.0+cu113)
# Requirement already satisfied: nltk in /usr/local/lib/python3.7/dist-packages (from sentence-transformers>=0.4.1->bertopic) (3.2.5)
# Collecting sentencepiece
#   Downloading sentencepiece-0.1.96-cp37-cp37m-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (1.2 MB)
#      |████████████████████████████████| 1.2 MB 39.1 MB/s
# Collecting huggingface-hub
#   Downloading huggingface_hub-0.5.1-py3-none-any.whl (77 kB)
#      |████████████████████████████████| 77 kB 6.4 MB/s
# Requirement already satisfied: typing-extensions in /usr/local/lib/python3.7/dist-packages (from torch>=1.6.0->sentence-transformers>=0.4.1->bertopic) (4.2.0)
# Requirement already satisfied: importlib-metadata in /usr/local/lib/python3.7/dist-packages (from transformers<5.0.0,>=4.6.0->sentence-transformers>=0.4.1->bertopic) (4.11.3)
# Collecting tokenizers!=0.11.3,<0.13,>=0.11.1
#   Downloading tokenizers-0.12.1-cp37-cp37m-manylinux_2_12_x86_64.manylinux2010_x86_64.whl (6.6 MB)
#      |████████████████████████████████| 6.6 MB 42.9 MB/s
# Requirement already satisfied: packaging>=20.0 in /usr/local/lib/python3.7/dist-packages (from transformers<5.0.0,>=4.6.0->sentence-transformers>=0.4.1->bertopic) (21.3)
# Requirement already satisfied: regex!=2019.12.17 in /usr/local/lib/python3.7/dist-packages (from transformers<5.0.0,>=4.6.0->sentence-transformers>=0.4.1->bertopic) (2019.12.20)
# Requirement already satisfied: requests in /usr/local/lib/python3.7/dist-packages (from transformers<5.0.0,>=4.6.0->sentence-transformers>=0.4.1->bertopic) (2.23.0)
# Collecting sacremoses
#   Downloading sacremoses-0.0.53.tar.gz (880 kB)
#      |████████████████████████████████| 880 kB 43.8 MB/s
# Collecting pyyaml<6.0
#   Downloading PyYAML-5.4.1-cp37-cp37m-manylinux1_x86_64.whl (636 kB)
#      |████████████████████████████████| 636 kB 45.2 MB/s
# Requirement already satisfied: filelock in /usr/local/lib/python3.7/dist-packages (from transformers<5.0.0,>=4.6.0->sentence-transformers>=0.4.1->bertopic) (3.6.0)
# Requirement already satisfied: pyparsing!=3.0.5,>=2.0.2 in /usr/local/lib/python3.7/dist-packages (from packaging>=20.0->transformers<5.0.0,>=4.6.0->sentence-transformers>=0.4.1->bertopic) (3.0.8)
# Requirement already satisfied: numba>=0.49 in /usr/local/lib/python3.7/dist-packages (from umap-learn>=0.5.0->bertopic) (0.51.2)
# Collecting pynndescent>=0.5
#   Downloading pynndescent-0.5.6.tar.gz (1.1 MB)
#      |████████████████████████████████| 1.1 MB 29.4 MB/s
# Requirement already satisfied: setuptools in /usr/local/lib/python3.7/dist-packages (from numba>=0.49->umap-learn>=0.5.0->bertopic) (57.4.0)
# Requirement already satisfied: llvmlite<0.35,>=0.34.0.dev0 in /usr/local/lib/python3.7/dist-packages (from numba>=0.49->umap-learn>=0.5.0->bertopic) (0.34.0)
# Requirement already satisfied: zipp>=0.5 in /usr/local/lib/python3.7/dist-packages (from importlib-metadata->transformers<5.0.0,>=4.6.0->sentence-transformers>=0.4.1->bertopic) (3.8.0)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.7/dist-packages (from requests->transformers<5.0.0,>=4.6.0->sentence-transformers>=0.4.1->bertopic) (2021.10.8)
# Requirement already satisfied: idna<3,>=2.5 in /usr/local/lib/python3.7/dist-packages (from requests->transformers<5.0.0,>=4.6.0->sentence-transformers>=0.4.1->bertopic) (2.10)
# Requirement already satisfied: urllib3!=1.25.0,!=1.25.1,<1.26,>=1.21.1 in /usr/local/lib/python3.7/dist-packages (from requests->transformers<5.0.0,>=4.6.0->sentence-transformers>=0.4.1->bertopic) (1.24.3)
# Requirement already satisfied: chardet<4,>=3.0.2 in /usr/local/lib/python3.7/dist-packages (from requests->transformers<5.0.0,>=4.6.0->sentence-transformers>=0.4.1->bertopic) (3.0.4)
# Requirement already satisfied: click in /usr/local/lib/python3.7/dist-packages (from sacremoses->transformers<5.0.0,>=4.6.0->sentence-transformers>=0.4.1->bertopic) (7.1.2)
# Requirement already satisfied: pillow!=8.3.*,>=5.3.0 in /usr/local/lib/python3.7/dist-packages (from torchvision->sentence-transformers>=0.4.1->bertopic) (7.1.2)
# Building wheels for collected packages: hdbscan, sentence-transformers, umap-learn, pynndescent, sacremoses
#   Building wheel for hdbscan (PEP 517) ... done
#   Created wheel for hdbscan: filename=hdbscan-0.8.28-cp37-cp37m-linux_x86_64.whl size=2330798 sha256=d7748544665d872460a582574fbb2157337b56234b586855a3dada351f9a5ebb
#   Stored in directory: /root/.cache/pip/wheels/6e/7a/5e/259ccc841c085fc41b99ef4a71e896b62f5161f2bc8a14c97a
#   Building wheel for sentence-transformers (setup.py) ... done
#   Created wheel for sentence-transformers: filename=sentence_transformers-2.2.0-py3-none-any.whl size=120747 sha256=623a65012f204ab08ebc30007d1a73a4b2af48e3bc134b6c751cf8f3656f44f2
#   Stored in directory: /root/.cache/pip/wheels/83/c0/df/b6873ab7aac3f2465aa9144b6b4c41c4391cfecc027c8b07e7
#   Building wheel for umap-learn (setup.py) ... done
#   Created wheel for umap-learn: filename=umap_learn-0.5.3-py3-none-any.whl size=82829 sha256=f79a693a02bed647d20f58ff8334e9e1b497921ccfcb72af6d802630ad3d1e99
#   Stored in directory: /root/.cache/pip/wheels/b3/52/a5/1fd9e3e76a7ab34f134c07469cd6f16e27ef3a37aeff1fe821
#   Building wheel for pynndescent (setup.py) ... done
#   Created wheel for pynndescent: filename=pynndescent-0.5.6-py3-none-any.whl size=53943 sha256=ae10b283482d29dbec2cca6e0350b53b3ea828350388ee3c1cadef020ac1281f
#   Stored in directory: /root/.cache/pip/wheels/03/f1/56/f80d72741e400345b5a5b50ec3d929aca581bf45e0225d5c50
#   Building wheel for sacremoses (setup.py) ... done
#   Created wheel for sacremoses: filename=sacremoses-0.0.53-py3-none-any.whl size=895260 sha256=d252585c61caa9145e16f31f539f580fbaa0f484d7d545bb12dc0fe5351db00e
#   Stored in directory: /root/.cache/pip/wheels/87/39/dd/a83eeef36d0bf98e7a4d1933a4ad2d660295a40613079bafc9
# Successfully built hdbscan sentence-transformers umap-learn pynndescent sacremoses
# Installing collected packages: pyyaml, tokenizers, sacremoses, huggingface-hub, transformers, sentencepiece, pynndescent, umap-learn, sentence-transformers, hdbscan, bertopic
#   Attempting uninstall: pyyaml
#     Found existing installation: PyYAML 3.13
#     Uninstalling PyYAML-3.13:
#       Successfully uninstalled PyYAML-3.13
# Successfully installed bertopic-0.10.0 hdbscan-0.8.28 huggingface-hub-0.5.1 pynndescent-0.5.6 pyyaml-5.4.1 sacremoses-0.0.53 sentence-transformers-2.2.0 sentencepiece-0.1.96 tokenizers-0.12.1 transformers-4.18.0 umap-learn-0.5.3

# %%
'''from sklearn.datasets import fetch_20newsgroups
docs = fetch_20newsgroups(subset='all',  remove=('headers', 'footers', 'quotes'))['data']'''

# %%
newsgroups_train = fetch_20newsgroups(subset='train', shuffle = True,remove=('headers', 'footers', 'quotes'))
newsgroups_test = fetch_20newsgroups(subset='test', shuffle = True,remove=('headers', 'footers', 'quotes'))

# %%
from sklearn.datasets import fetch_20newsgroups
docs = fetch_20newsgroups(subset='all',  remove=('headers', 'footers', 'quotes'))['data']

# %%
from bertopic import BERTopic

topic_model = BERTopic(language="english", calculate_probabilities=True, verbose=True)
topics, probs = topic_model.fit_transform(docs)
# Out:
# Downloading:   0%|          | 0.00/1.18k [00:00<?, ?B/s]
# Downloading:   0%|          | 0.00/190 [00:00<?, ?B/s]
# Downloading:   0%|          | 0.00/10.2k [00:00<?, ?B/s]
# Downloading:   0%|          | 0.00/612 [00:00<?, ?B/s]
# Downloading:   0%|          | 0.00/116 [00:00<?, ?B/s]
# Downloading:   0%|          | 0.00/39.3k [00:00<?, ?B/s]
# Downloading:   0%|          | 0.00/349 [00:00<?, ?B/s]
# Downloading:   0%|          | 0.00/90.9M [00:00<?, ?B/s]
# Downloading:   0%|          | 0.00/53.0 [00:00<?, ?B/s]
# Downloading:   0%|          | 0.00/112 [00:00<?, ?B/s]
# Downloading:   0%|          | 0.00/466k [00:00<?, ?B/s]
# Downloading:   0%|          | 0.00/350 [00:00<?, ?B/s]
# Downloading:   0%|          | 0.00/13.2k [00:00<?, ?B/s]
# Downloading:   0%|          | 0.00/232k [00:00<?, ?B/s]
# Batches:   0%|          | 0/589 [00:00<?, ?it/s]
# 2022-05-04 06:34:50,387 - BERTopic - Transformed documents to Embeddings
# /usr/local/lib/python3.7/dist-packages/numba/np/ufunc/parallel.py:363: NumbaWarning: The TBB threading layer requires TBB version 2019.5 or later i.e., TBB_INTERFACE_VERSION >= 11005. Found TBB_INTERFACE_VERSION = 9107. The TBB threading layer is disabled.
#   warnings.warn(problem)
# 2022-05-04 06:35:36,462 - BERTopic - Reduced dimensionality
# 2022-05-04 06:36:18,556 - BERTopic - Clustered reduced embeddings

# %%
freq = topic_model.get_topic_info(); freq.head(21)
# Out:
#     Topic  Count                                Name
# 0      -1   3604                    -1_to_the_and_of
# 1       0   1070               0_team_game_he_season
# 2       1    509                1_patients_msg_of_is
# 3       2    435           2_space_launch_nasa_lunar
# 4       3    355       3_key_chip_clipper_encryption
# 5       4    309                 4_hello_ites_hi_huh
# 6       5    236          5_israel_israeli_arab_jews
# 7       6    179              6_god_atheists_is_that
# 8       7    171             7_jpeg_image_gif_format
# 9       8    167          8_fbi_koresh_batf_compound
# 10      9    151         9_motherboard_sale_ram_card
# 11     10    142               10_db_windows_mov_dos
# 12     11    136             11_car_cars_engine_ford
# 13     12    133             12_you_context_jim_your
# 14     13    127        13_xterm_symbol_x11r5_server
# 15     14    110        14_amp_audio_offer_condition
# 16     15    102  15_window_widget_application_event
# 17     16     86      16_requests_send_address_email
# 18     17     85     17_den_points_polygon_algorithm
# 19     18     81           18_bike_tires_tire_fluids
# 20     19     78             19_printer_ink_print_hp

# %%
topic_model.get_topic(5)
# Out:
# [('israel', 0.024074024856876344),
#  ('israeli', 0.020325050960449734),
#  ('arab', 0.012783039399572664),
#  ('jews', 0.009677422976598482),
#  ('arabs', 0.00926647133998574),
#  ('the', 0.008074633060010009),
#  ('of', 0.008058484544822506),
#  ('palestinian', 0.007765612481772983),
#  ('not', 0.007731500564640954),
#  ('in', 0.007342878140396189)]

# %%
topic_model.visualize_topics()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script src="https://cdn.plot.ly/plotly-2.8.3.min.js"></script>                <div id="55a926e9-0a7a-493d-a0ff-2ff97d118fd4" class="plotly-graph-div" style="height:650px; width:650px;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("55a926e9-0a7a-493d-a0ff-2ff97d118fd4")) {                    Plotly.newPlot(                        "55a926e9-0a7a-493d-a0ff-2ff97d118fd4",                        [{"customdata":[[1,"key | clipper | chip | encryption | keys",591],[2,"abo | ites | cheek | yep | huh",526],[3,"israel | israeli | jews | arab | jewish",476],[4,"gun | guns | firearms | militia | amendment",357],[5,"bike | riding | ride | car | my",266],[6,"card | drivers | diamond | driver | ati",190],[7,"amp | audio | stereo | condition | asking",183],[8,"bike | tires | bikes | tire | miles",168],[9,"car | cars | engine | ford | mustang",164],[10,"jpeg | image | gif | format | images",163],[11,"printer | print | hp | deskjet | printers",148],[12,"drive | drives | dis
637814,0.00855338170432954,0.007166895248979756,0.006150701608438987,0.006687435851207109,0.005916014204173017,0.006449135005316889,0.006684399990811461,0.006059749594786498,0.0070862103257285395,0.005817783962874628,0.005890989109365265,0.0059048677923895475,0.006160894192843502,0.005687206257353456,0.0067268500790029434,0.006212712674797775,0.009048881278379148,0.006879168095913887,0.006236144511327962,0.005872910832499923,0.006657301827119416,0.007092894986713168,0.00584151597891361,0.005914065948630296,0.006798814959803888,0.006420161085176242,0.00514734398283965,0.008676585066214857,0.00793153376088533],"y":["<b>Topic 3</b>: israel_israeli_jews_arab...","<b>Topic 4</b>: gun_guns_firearms_militi...","<b>Topic 16</b>: armenian_armenians_turk...","<b>Topic 17</b>: moral_objective_moralit...","<b>Topic 20</b>: fire_fbi_started_bds_ga...","<b>Topic 21</b>: islam_quran_islamic_rus...","<b>Topic 23</b>: you_post_your_sternligh...","<b>Topic 25</b>: serbs_muslims_stephanop...","<b>Topic 27</b>: homosexuality_homosexua...","<b>Topic 35</b>: tax_taxes_income_defici...","<b>Topic 36</b>: batf_warrant_raid_assau...","<b>Topic 38</b>: bolick_maddi_hausmann_s...","<b>Topic 40</b>: kinsey_sex_men_gay_sexu...","<b>Topic 47</b>: mary_her_she_bernadette...","<b>Topic 48</b>: koresh_fbi_batf_childre...","<b>Topic 49</b>: judas_books_bible_scrip...","<b>Topic 57</b>: kuwait_iran_iraq_gulf_a...","<b>Topic 62</b>: hell_eternal_heaven_god...","<b>Topic 64</b>: atheists_atheism_god_at...","<b>Topic 66</b>: reno_waco_president_fed...","<b>Topic 68</b>: greek_greece_turkish_gr...","<b>Topic 74</b>: government_libertarians...","<b>Topic 75</b>: jehovah_elohim_lord_mor...","<b>Topic 76</b>: ra_satan_god_thou_lucif...","<b>Topic 81</b>: god_exist_existence_why...","<b>Topic 84</b>: trial_weaver_spence_coo...","<b>Topic 86</b>: were_they_her_azerbaija...","<b>Topic 88</b>: gay_homosexuals_sexual_...","<b>Topic 96</b>: god_christ_shall_jesus_...","<b>Topic 97</b>: marriage_married_marry_...","<b>Topic 99</b>: silence_moment_schools_...","<b>Topic 102</b>: penalty_cruel_death_pu...","<b>Topic 108</b>: prophecies_prophecy_sc...","<b>Topic 111</b>: abortion_women_rape_ab...","<b>Topic 116</b>: god_atheism_believe_be...","<b>Topic 118</b>: truth_absolute_bible_a...","<b>Topic 120</b>: law_jesus_god_paul_sin","<b>Topic 129</b>: aaron_baptism_sin_fait...","<b>Topic 133</b>: tomb_resurrection_jesu...","<b>Topic 134</b>: duke_gritz_panicking_q...","<b>Topic 140</b>: pope_church_schism_cre...","<b>Topic 146</b>: god_son_jesus_father_h...","<b>Topic 159</b>: humankind_weatherhead_...","<b>Topic 160</b>: professors_schools_uni...","<b>Topic 161</b>: zane_2ti_church_book_f...","<b>Topic 164</b>: easter_resurrection_pa...","<b>T ...

# %%
cleaned_docs = topic_model._preprocess_text(docs)

# %%
vectorizer = topic_model.vectorizer_model
tokenizer = vectorizer.build_tokenizer()
tokens = [tokenizer(doc) for doc in cleaned_docs]
dictionary = corpora.Dictionary(tokens)
corpus = [dictionary.doc2bow(token) for token in tokens]
topic_words = [[words for words, _ in topic_model.get_topic(topic)] 
               for topic in range(len(set(topics))-1)]
# Evaluate
coherence_model = CoherenceModel(topics=topic_words, 
                                 texts=tokens, 
                                 corpus=corpus,
                                 dictionary=dictionary, 
                                 coherence='c_v')
coherence = coherence_model.get_coherence()

# %%
coherence
# Out:
# 0.6036499551933779

# %%
coherence_model2 = CoherenceModel(topics=topic_words, 
                                 texts=tokens, 
                                 corpus=corpus,
                                 dictionary=dictionary, 
                                 coherence='u_mass')
coherence2= coherence_model2.get_coherence()

# %%
coherence2
# Out:
# -4.636863585126087

# %%
coherence_model3 = CoherenceModel(topics=topic_words, 
                                 texts=tokens, 
                                 corpus=corpus,
                                 dictionary=dictionary, 
                                 coherence='c_npmi')
coherence3= coherence_model3.get_coherence()

# %%
coherence3
# Out:
# 0.04910718878914391
